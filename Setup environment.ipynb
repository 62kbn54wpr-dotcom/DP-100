# %% [markdown]
# # Preparation of the System
#
# ## Installation of Azure CLI
# Installation of Azure CLI throough running the following command from the system Terminal
# > brew update && install azure-cli
#
# ## Create .venv
# Use the latest Python version installed through brew
#
# Omit .venv from replication through GitHub
#
# ## Installation of .env to keep secrets out of the code
# Run the following command from the .venv Terminal
# > pip3 install python-dotenv
#
# Possibly you need to install the package as follows:

# %%
# !python3 -m venv /Users/markgoossens/Documents/GitHub/DP-100/.venv
# !source /Users/markgoossens/Documents/GitHub/DP-100/.venv/bin/activate
# !python3 -m pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.14/site-packages (1.2.1)

# %% [markdown]
# Create a .txt file with the secrets in to in the form
# >Key (secret) = Value
#
# For Azure, the following secrets may be of interest:
# - AZURE_RESOURCE_GROUP_NAME # Preferred resource group name
# - LOCATION # Preferred Azure region
# - AZURE_SUBSCRIPTION_ID # subscription ID obtained through 'az account show --query id --output tsv'
#
# Omit .env from replication through GitHub

# %% [markdown]
# ## Additiojnal packages
#
# Create a new .txt file ans save it as requirements.txt
#
# Enter the following packages in the file:
# - azure-mgmt-resources
# - azure-identity
#
# Run the following command to install the packages as listed iin requirements.txt

# %%
# !python3 -m venv /Users/markgoossens/Documents/GitHub/DP-100/.venv
# !source /Users/markgoossens/Documents/GitHub/DP-100/.venv/bin/activate
# !python3 -m pip install -r requirements.txt
# Out:
# Collecting azure-mgmt-resource (from -r requirements.txt (line 1))
#   Downloading azure_mgmt_resource-24.0.0-py3-none-any.whl.metadata (43 kB)
# Collecting azure-identity (from -r requirements.txt (line 2))
#   Downloading azure_identity-1.25.1-py3-none-any.whl.metadata (88 kB)
# Collecting isodate>=0.6.1 (from azure-mgmt-resource->-r requirements.txt (line 1))
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions>=4.6.0 (from azure-mgmt-resource->-r requirements.txt (line 1))
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting azure-common>=1.1 (from azure-mgmt-resource->-r requirements.txt (line 1))
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting azure-mgmt-core>=1.5.0 (from azure-mgmt-resource->-r requirements.txt (line 1))
#   Downloading azure_mgmt_core-1.6.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting azure-core>=1.31.0 (from azure-identity->-r requirements.txt (line 2))
#   Downloading azure_core-1.38.0-py3-none-any.whl.metadata (47 kB)
# Collecting cryptography>=2.5 (from azure-identity->-r requirements.txt (line 2))
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity->-r requirements.txt (line 2))
#   Downloading msal-1.34.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->-r requirements.txt (line 2))
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting requests>=2.21.0 (from azure-core>=1.31.0->azure-identity->-r requirements.txt (line 2))
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting cffi>=2.0.0 (from cryptography>=2.5->azure-identity->-r requirements.txt (line 2))
#   Using cached cffi-2.0.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=2.5->azure-identity->-r requirements.txt (line 2))
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r requirements.txt (line 2))
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity->-r requirements.txt (line 2))
#   Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity->-r requirements.txt (line 2))
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity->-r requirements.txt (line 2))
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity->-r requirements.txt (line 2))
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading azure_mgmt_resource-24.0.0-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 22.3 MB/s  0:00:00
# Downloading azure_identity-1.25.1-py3-none-any.whl (191 kB)
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_core-1.38.0-py3-none-any.whl (217 kB)
# Downloading azure_mgmt_core-1.6.0-py3-none-any.whl (29 kB)
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 22.7 MB/s  0:00:00 eta 0:00:01
# Using cached cffi-2.0.0-cp314-cp314-macosx_11_0_arm64.whl (181 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.34.0-py3-none-any.whl (116 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: azure-common, urllib3, typing-extensions, PyJWT, pycparser, isodate, idna, charset_normalizer, certifi, requests, cffi, cryptography, azure-core, azure-mgmt-core, msal, azure-mgmt-resource, msal-extensions, azure-identity
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [azure-identity]m [azure-mgmt-resource]
# Successfully installed PyJWT-2.10.1 azure-common-1.1.28 azure-core-1.38.0 azure-identity-1.25.1 azure-mgmt-core-1.6.0 azure-mgmt-resource-24.0.0 certifi-2026.1.4 cffi-2.0.0 charset_normalizer-3.4.4 cryptography-46.0.3 idna-3.11 isodate-0.7.2 msal-1.34.0 msal-extensions-1.3.1 pycparser-2.23 requests-2.32.5 typing-extensions-4.15.0 urllib3-2.6.3
