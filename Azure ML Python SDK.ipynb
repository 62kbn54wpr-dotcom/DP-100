# %%
# import os

from azure.identity import DefaultAzureCredential
from azure.mgmt.resource import ResourceManagementClient

from dotenv import dotenv_values
config = dotenv_values(".env")

# %%
subscription_id = config.get("AZURE_SUBSCRIPTION_ID")
resource_group = config.get("AZURE_RESOURCE_GROUP_NAME")
workspace = config.get("AZURE_ML_WORKSPACE_NAME")

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient(
    DefaultAzureCredential(), subscription_id, resource_group, workspace
)
# Out:
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
from azure.ai.ml.entities import Workspace

workspace_name = "mlw-example"

ws_basic = Workspace(
    name=workspace,
    # location= config.get("LOCATION"),
    display_name="DP-100 workspace",
    description="ML workspace for DP-100 exam preparation",
)
poller = ml_client.workspaces.begin_update(ws_basic)
result = poller.result()

# %%
poller.result()
# Out:
# Workspace({'kind': 'default', 'print_as_yaml': False, 'discovery_url': 'https://westeurope.api.azureml.ms/discovery', 'mlflow_tracking_uri': 'azureml://westeurope.api.azureml.ms/mlflow/v1.0/subscriptions/5f74b5e4-15e0-4f8e-b0a0-bd1fd913279a/resourceGroups/DP-100_Azure_Data_Scientist_Associate/providers/Microsoft.MachineLearningServices/workspaces/DP-100_Machine_Learning_Service', 'workspace_id': '106cecb4-5654-4cde-a410-b09a644d2680', 'feature_store_settings': None, 'name': 'DP-100_Machine_Learning_Service', 'description': 'ML workspace for DP-100 exam preparation', 'tags': {}, 'properties': {}, 'id': '/subscriptions/5f74b5e4-15e0-4f8e-b0a0-bd1fd913279a/resourceGroups/DP-100_Azure_Data_Scientist_Associate/providers/Microsoft.MachineLearningServices/workspaces/DP-100_Machine_Learning_Service', 'Resource__source_path': '', 'base_path': '/Users/markgoossens/Documents/GitHub/DP-100', 'creation_context': None, 'serialize': <msrest.serialization.Serializer object at 0x11c7e3b60>, 'display_
# ...

# %%
poller.result().name
# Out:
# 'DP-100_Machine_Learning_Service'
