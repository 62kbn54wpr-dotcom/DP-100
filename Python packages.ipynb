# %% [markdown]
# # Python packages installed:
#
# ## Installation of .env to store secrets
#
# > pip install python-dotenv
#
# Retreive the secrets from .env through
#
# > from dotenv import load_dotenv
#
# > load_dotenv()
#
#
# ## Setup of he device to interact with AZURE
# First install AZURE CLI on the system via the Terminal through:
#
# > brew update && brew install azure-cli
#
# Set environment variables as:
# >#!/bin/bash
# >- export AZURE_RESOURCE_GROUP_NAME=<ResourceGroupName> # Change to your preferred resource group name
# >- export LOCATION=<Location> # Change to your preferred region
# >- export AZURE_SUBSCRIPTION_ID="$(az account show --query id --output tsv)"
#
# This may require an update of the login parameters.  To do so, run 'az login' and select the appropriate options.
#
# # Additional packages
# The following packages were installed through the Terminal:
#
# Create a text file with the following packages in and name it 'requirements.txt':
# - azure-mgmt-resource
# - azure-identity
#
# Then run
# > pip install -r requirements.txt' in the Terminal linked to the .venv
#
#
#
#
#
#
# 1. pip install azure-ai-ml
